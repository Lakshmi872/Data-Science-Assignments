# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# 1.Data Cleaning and Preparation:

# %%
df = pd.read_csv(r"Cardiotocographic[1].csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#As per Assignment given , with its detailed information .

#In assignment , only 11 columns were given , but in dataset we have extra 3 columns given i.e Width , Tendency , NSP.

#As ,not having knowledge about the extra 3 columns given in dataset , so removing it , for doing the EDA by given Assignmnet information

# %%
df = df.drop(columns=['Width','Tendency','NSP'])
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV
# 0      0.5  43.000000   2.4
# 1      2.1   0.000000  10.4
# ...

# %%
df.dtypes
# Out:
# LB      float64
# AC      float64
# FM      float64
# UC      float64
# DL      float64
# DS      float64
# DP      float64
# ASTV    float64
# MSTV    float64
# ALTV    float64
# MLTV    float64
# dtype: object

# %%
df.shape
# Out:
# (2126, 11)

# %%
df.describe()
# LB , AC , DS , DP , MLTV , Width , Tendency , NSP = Missing values
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LB      2105 non-null   float64
#  1   AC      2106 non-null   float64
#  2   FM      2126 non-null   float64
#  3   UC      2126 non-null   float64
#  4   DL      2126 non-null   float64
#  5   DS      2105 non-null   float64
#  6   DP      2105 non-null   float64
#  7   ASTV    2126 non-null   float64
#  8   MSTV    2126 non-null   float64
#  9   ALTV    2126 non-null   float64
#  10  MLTV    2105 non-null   float64
# dtypes: float64(11)
# memory usage: 182.8 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df[df.duplicated()]  # duplicated records
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 68    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 791   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 1115  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1381  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1458  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
#
#       MSTV  ALTV  MLTV
# 68     1.2   0.0  10.3
# 791    0.9   4.0  14.8
# 1115   1.9   0.0  15.1
# 1381   1.5   0.0   0.0
# 1458   0.9   0.0  10.6

# %%
df[df.duplicated(keep=False)]  # duplicated records, its original index and duplicated index
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 67    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 68    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 790   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 791   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 1113  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1115  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1380  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1381  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1457  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
# 1458  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
#
#       MSTV  ALTV  MLTV
# 67     1.2   0.0  10.3
# 68     1.2   0.0  10.3
# 790    0.9   4.0  14.8
# 791    0.9   4.0  14.8
# 1113   1.9   0.0  15.1
# ...

# %%
df.shape
# Out:
# (2126, 11)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2121, 11)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 2.Handling Missing values

# %%
df.isna()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
df.isnull().sum()
# Out:
# LB      21
# AC      20
# FM       0
# UC       0
# DL       0
# DS      21
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
# Drop Columns

# %%
df.isna().sum()
# Out:
# LB      21
# AC      20
# FM       0
# UC       0
# DL       0
# DS      21
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
# visualize the missing values:-
sns.heatmap(df.isna()) # white horizontals are missing values
plt.show()

# %%
len(df)
# Out:
# 2121

# %%
# %of missing values
for i in df.isna().sum():
    print((i/len(df))*100)
# Out:
# 0.9900990099009901
# 0.942951438000943
# 0.0
# 0.0
# 0.0
# 0.9900990099009901
# 0.9900990099009901
# 0.0
# 0.0
# 0.0
# 0.9900990099009901

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
df.boxplot()
plt.show()

# %%
# LB ,ASTV , MSTV , ALTV , MLTV  cloumns :- outliers are present , therefore we will replace the missing values with medain
# AC , DS , DP  columns :-  no outliers are present , therefore we will replace the missing values with mean

# %%
LB_median = df['LB'].median()
LB_median
# Out:
# 133.0

# %%
df['LB'].fillna(LB_median,inplace=True)

# %%
df.isna().sum()
# Out:
# LB       0
# AC      20
# FM       0
# UC       0
# DL       0
# DS      21
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
AC_mean = df['AC'].mean()
AC_mean
# Out:
# np.float64(0.003219663782219371)

# %%
df['AC'].fillna(AC_mean,inplace=True)

# %%
df.isna().sum()
# Out:
# LB       0
# AC       0
# FM       0
# UC       0
# DL       0
# DS      21
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
DS_mean = df['DS'].mean()
DS_mean
# Out:
# np.float64(2.5149572759619747e-06)

# %%
df['DS'].fillna(DS_mean,inplace=True)

# %%
df.isna().sum()
# Out:
# LB       0
# AC       0
# FM       0
# UC       0
# DL       0
# DS       0
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
df['DP'].fillna(df['DP'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# LB       0
# AC       0
# FM       0
# UC       0
# DL       0
# DS       0
# DP       0
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV    21
# dtype: int64

# %%
df['MLTV'].fillna(df['MLTV'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# LB       0
# AC       0
# FM       0
# UC       0
# DL       0
# DS       0
# DP      21
# ASTV     0
# MSTV     0
# ALTV     0
# MLTV     0
# dtype: int64

# %%
# all the missing values are now replaced with either mean or median , and now again observing the missing values using visualization

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
df.boxplot()
plt.show()

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2100.000000  2101.000000  2121.000000  2121.000000  2121.000000
# mean    133.299164     0.003220     0.009916     0.004396     0.001897
# std       9.976126     0.004394     0.067618     0.003341     0.003345
# min     105.000000    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001862     0.000000
# 50%     133.000000     0.001631     0.000000     0.004505     0.000000
# 75%     140.010442     0.005650     0.002567     0.006536     0.003289
# max     161.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2100.000000  2100.000000  2121.000000  2121.000000  2121.000000
# mean      0.000003     0.000175    47.028035     1.364577    10.308326
# std       0.000142     0.000840    18.816833     1.174862    21.224880
# ...

# %%
# now to treat the outliers we have :- 
# capping :- Replacing outlier values 
# in capping all outlier values will be replaced by upper extreme or lower extreme values

# %%
df['LB'].quantile(0.25)   # lower quartile:-q1   it means that there are 25 % values which are less than 126
# Out:
# np.float64(126.0)

# %%
df['LB'].quantile(0.75)     # upper quartile:-q3   it means that there are 75 % values which are less thn 140 , only 25 % values are greater thn 140
# Out:
# np.float64(140.01044215283778)

# %%
# outlier Detection :- user defined function to calculate upper extreme and lower extreme values

# %%
def outlier_detection(data,colname):
    q1 = data[colname].quantile(0.25)
    q3 = data[colname].quantile(0.75)
    iqr = q3-q1

    upper_extreme = q3 + (1.5*iqr)
    lower_extreme = q1 - (1.5*iqr)

    return print('lower_extreme:-',lower_extreme,', upper_extreme:-',upper_extreme,', q1:-',q1,', q3:-',q3)

# %%
outlier_detection(df,'LB')   # so replacing all the upper extreme outliers which are greater thn 161 are replaced by 161
# Out:
# lower_extreme:- 104.98433677074333 , upper_extreme:- 161.02610538209444 , q1:- 126.0 , q3:- 140.01044215283778

# %%
# extract all values of LB column which are greater than upper extreme i.e 161
df[df['LB']>161]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV]
# Index: []

# %%
df[df['LB']>161].shape[0]
# Out:
# 0

# %%
#or
len(df[df['LB']>161])
# Out:
# 0

# %%
# now all these 6 outlier values of LB column should be replaced by upper extreme value = 161 for only LB column
df.loc[df['LB']>161,'LB']
# Out:
# Series([], Name: LB, dtype: float64)

# %%
# capping outliers of LB column
df.loc[df['LB']>161,'LB'] = 161

# %%
df[df['LB']>161] # no values are displayed .... as all outliers are replaced by 161
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV]
# Index: []

# %%
df[df['LB']==161]
# Out:
#          LB        AC        FM        UC        DL        DS   DP       ASTV  \
# 411   161.0  0.000000  0.000000  0.001595  0.001595  0.000000  0.0  71.000000
# 610   161.0  0.002469  0.002469  0.002469  0.000000  0.000004  0.0  35.000000
# 612   161.0  0.005181  0.012953  0.002591  0.000000  0.000000  0.0  39.442226
# 1103  161.0  0.006972  0.000000  0.002960  0.000000  0.000000  0.0  19.000000
# 1406  161.0  0.005068  0.000000  0.001689  0.000000  0.000000  0.0  46.000000
# 1504  161.0  0.006189  0.000000  0.006189  0.000000  0.000000  0.0  38.000000
#
#           MSTV  ALTV  MLTV
# 411   0.300000  17.0   5.8
# 610   1.798149   0.0  24.7
# 612   1.600000   0.0  10.0
# 1103  2.300000   0.0  12.1
# 1406  0.800000   0.0   8.6
# 1504  1.000000   0.0   8.1

# %%
df[df['LB']==161].shape[0]  # so all 6 outliers of only LB  are now replaced by 161
# Out:
# 6

# %%
df[df['LB']<105]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV]
# Index: []

# %%
# now all these 4 outlier values of LB column should be replaced by lower extreme value = 105 for only LB column
df.loc[df['LB']<105,'LB']
# Out:
# Series([], Name: LB, dtype: float64)

# %%
df.loc[df['LB']<105,'LB'] = 105

# %%
df[df['LB']<105]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV]
# Index: []

# %%
outlier_detection(df,'AC')
# Out:
# lower_extreme:- -0.008474577 , upper_extreme:- 0.014124295 , q1:- 0.0 , q3:- 0.005649718

# %%
df.loc[df['AC']>0.01403017,'AC'] = 0.01403017   # upper extreme outliers of AC are replced by upper extreme value

# %%
df.loc[df['AC']<-0.008418102,'AC'] = -0.008418102   # lower extreme outliers of AC are replced by lower extreme value

# %%
outlier_detection(df,'FM')
# Out:
# lower_extreme:- -0.003851091 , upper_extreme:- 0.006418485 , q1:- 0.0 , q3:- 0.002567394

# %%
df.loc[df['FM']>0.0064210543750000005,'FM'] = 0.0064210543750000005   # upper extreme outliers of FM are replced by upper extreme valu

# %%
df.loc[df['FM']<-0.003852632625,'FM'] = -0.003852632625   # lower extreme outliers of FM are replced by lower extreme value

# %%
outlier_detection(df,'UC')
# Out:
# lower_extreme:- -0.005148429500000001 , upper_extreme:- 0.0135465745 , q1:- 0.001862197 , q3:- 0.006535948

# %%
df.loc[df['UC']>0.013552377624999999,'UC'] = 0.013552377624999999   # upper extreme outliers of UC are replced by upper extreme valu

# %%
df.loc[df['UC']<-0.005158101374999999,'UC'] = -0.005158101374999999   # lower extreme outliers of UC are replced by lower extreme value

# %%
outlier_detection(df,'DL')
# Out:
# lower_extreme:- -0.004934211 , upper_extreme:- 0.008223685 , q1:- 0.0 , q3:- 0.003289474

# %%
df.loc[df['DL']>0.00823047,'DL'] = 0.00823047   # upper extreme outliers of DL are replced by upper extreme valu

# %%
df.loc[df['DL']<-0.0049382820000000004,'DL'] = -0.0049382820000000004   # lower extreme outliers of DL are replced by lower extreme value

# %%
outlier_detection(df,'DS')
# Out:
# lower_extreme:- 0.0 , upper_extreme:- 0.0 , q1:- 0.0 , q3:- 0.0

# %%
df.loc[df['DS']>0.0,'DS'] = 0.0   # upper extreme outliers of DS are replced by upper extreme valu

# %%
df.loc[df['DS']<0.0,'DS'] = 0.0   # lower extreme outliers of DS are replced by lower extreme value

# %%
outlier_detection(df,'ASTV')
# Out:
# lower_extreme:- -11.5 , upper_extreme:- 104.5 , q1:- 32.0 , q3:- 61.0

# %%
df.loc[df['ASTV']>104.5,'ASTV'] = 104.5   # upper extreme outliers of ASTV are replced by upper extreme valu

# %%
df.loc[df['ASTV']< -11.5,'ASTV'] = -11.5   # lower extreme outliers of ASTV are replced by lower extreme value

# %%
outlier_detection(df,'DP')
# Out:
# lower_extreme:- 0.0 , upper_extreme:- 0.0 , q1:- 0.0 , q3:- 0.0

# %%
df.loc[df['DP']>0.0,'DP'] = 0.0   # upper extreme outliers of DP are replced by upper extreme valu

# %%
df.loc[df['DP']<0.0,'DP'] = 0.0   # lower extreme outliers of DP are replced by lower extreme value

# %%
outlier_detection(df,'MSTV')
# Out:
# lower_extreme:- -0.8 , upper_extreme:- 3.2 , q1:- 0.7 , q3:- 1.7

# %%
df.loc[df['MSTV']>3.2,'MSTV'] = 3.2   # upper extreme outliers of MSTV are replced by upper extreme valu

# %%
df.loc[df['MSTV']<-0.8,'MSTV'] = -0.8   # lower extreme outliers of MSTV are replced by lower extreme value

# %%
outlier_detection(df,'ALTV')
# Out:
# lower_extreme:- -16.5 , upper_extreme:- 27.5 , q1:- 0.0 , q3:- 11.0

# %%
df.loc[df['ALTV']>27.5,'ALTV'] = 27.5   # upper extreme outliers of ALTV are replced by upper extreme valu

# %%
df.loc[df['ALTV']<-16.5,'ALTV'] = -16.5   # lower extreme outliers of ALTV are replced by lower extreme value

# %%
outlier_detection(df,'MLTV')
# Out:
# lower_extreme:- -4.850000000000001 , upper_extreme:- 20.35 , q1:- 4.6 , q3:- 10.9

# %%
df.loc[df['MLTV']>20.1,'MLTV'] = 20.1   # upper extreme outliers of MLTV are replced by upper extreme valu

# %%
df.loc[df['MLTV']<-4.7,'MLTV'] = -4.7  # lower extreme outliers of MLTV are replced by lower extreme value

# %%
df.boxplot()
plt.show()

# %%
df['LB'].value_counts()   # having unique values with its frequency
# Out:
# LB
# 133.000000    129
# 130.000000    105
# 122.000000    102
# 138.000000     98
# 125.000000     87
#              ...
# 132.889401      1
# 132.974406      1
# 135.172761      1
# 134.878101      1
# 124.919186      1
# Name: count, Length: 151, dtype: int64

# %%
df['AC'].value_counts()
# Out:
# AC
# 0.000000    831
# 0.014030     38
# 0.000834     13
# 0.005004      9
# 0.002502      9
#            ...
# 0.007865      1
# 0.007099      1
# 0.006747      1
# 0.007488      1
# 0.007321      1
# Name: count, Length: 1036, dtype: int64

# %%
df['FM'].value_counts()
# Out:
# FM
# 0.000000    1228
# 0.006421     340
# 0.000834      10
# 0.003336       9
# 0.001668       9
#             ...
# 0.001291       1
# 0.001988       1
# 0.003467       1
# 0.004193       1
# 0.005420       1
# Name: count, Length: 467, dtype: int64

# %%
df['UC'].value_counts()
# Out:
# UC
# 0.000000    316
# 0.000834     24
# 0.001668     15
# 0.002502     12
# 0.004170     10
#            ...
# 0.010493      1
# 0.008143      1
# 0.007742      1
# 0.008306      1
# 0.006380      1
# Name: count, Length: 1359, dtype: int64

# %%
df['DL'].value_counts()
# Out:
# DL
#  0.000000    1162
#  0.008230     119
#  0.000834      22
#  0.001668       6
# -0.004938       6
#              ...
#  0.001280       1
#  0.008039       1
#  0.000898       1
#  0.001127       1
#  0.005000       1
# Name: count, Length: 710, dtype: int64

# %%
df['DS'].value_counts()   # can drop this column , as column contains only 0  as its unique value , so no point to keep it in dataframe
# Out:
# DS
# 0.0    2100
# Name: count, dtype: int64

# %%
df['DP'].value_counts() # can drop this column , as column contains only 0  as its unique value , so no point to keep it in dataframe
# Out:
# DP
# 0.0    2100
# Name: count, dtype: int64

# %%
df['ASTV'].value_counts() # its very important column ,cant drop this column
# Out:
# ASTV
# 65.000000    60
# 58.000000    57
# 60.000000    57
# 64.000000    56
# 61.000000    53
#              ..
# 61.924352     1
# 68.390962     1
# 69.945069     1
# 77.961645     1
# 66.449294     1
# Name: count, Length: 183, dtype: int64

# %%
df['MSTV'].value_counts()    # its very important column ,cant drop this column
# Out:
# MSTV
# 0.500000    116
# 0.800000    116
# 1.300000    114
# 0.400000    114
# 0.700000    112
#            ...
# 0.495823      1
# 1.048883      1
# 0.823408      1
# 0.790002      1
# 0.359472      1
# Name: count, Length: 134, dtype: int64

# %%
df['ALTV'].value_counts()
# Out:
# ALTV
#  0.000000     1164
#  27.500000     315
#  1.000000       48
#  2.000000       44
#  5.000000       39
#               ...
# -0.133584        1
# -0.150082        1
#  0.481507        1
#  0.453936        1
#  26.428179       1
# Name: count, Length: 120, dtype: int64

# %%
df['MLTV'].value_counts()
# Out:
# MLTV
#  0.000000     123
#  20.100000     76
#  7.100000      29
#  6.700000      26
#  5.200000      23
#              ...
#  0.144354       1
# -0.172075       1
#  4.054948       1
#  3.526901       1
#  4.934339       1
# Name: count, Length: 296, dtype: int64

# %%
# Drop columns

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV  MLTV
# 0      0.5  27.5   2.4
# 1      2.1   0.0  10.4
# ...

# %%
df.drop(columns=['DS','DP'],inplace=True)

# %%
df  # removed DS , DP column
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV
# 0      2.4
# 1     10.4
# 2     13.4
# 3     20.1
# ...

# %%
# 2.Statistical Summary:

# %%
df
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV
# 0      2.4
# 1     10.4
# 2     13.4
# 3     20.1
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2100.000000  2101.000000  2121.000000  2121.000000  2121.000000
# mean    133.299164     0.003147     0.001570     0.004367     0.001773
# std       9.976126     0.003847     0.002488     0.003001     0.002670
# min     105.000000    -0.008418    -0.003853    -0.005158    -0.004938
# 25%     126.000000     0.000000     0.000000     0.001862     0.000000
# 50%     133.000000     0.001631     0.000000     0.004505     0.000000
# 75%     140.010442     0.005650     0.002567     0.006536     0.003289
# max     161.000000     0.014030     0.006421     0.013552     0.008230
#
#               ASTV         MSTV         ALTV         MLTV
# count  2121.000000  2121.000000  2121.000000  2100.000000
# mean     47.013891     1.304702     6.705567     8.008421
# std      17.612897     0.781791    10.386391     5.069776
# min     -11.500000    -0.800000   -16.500000    -4.700000
# ...

# %%
#count:- 
#For all the columns the total count means total number of rows/records/observations is :- 2124
# but columns such as FM , UC , ASTV , MSTV , ALTV ,  contains all values and no missing values i.e no null or NA values
# whereas columns such as LB , AC , DS , MLTV , Width , Tendency

# %%
# mean and median:- median = 50% in describe function
 #LB :-           mean = 133.342023 and median = 133       ,   mean>median = normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side  
 #AC :-        mean = 0.003220 and median = 0.001634,  mean>median = normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side   
 #FM :-        mean = 0.009904 and median = 0.000000 , mean>median = normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side   
 #UC :-      mean = 0.004394 and median = 0.004486      ,  mean<median = normal distribution curve  with small -ve skewness /left skewed/outliers present at left hand side 
 #DL: -     mean = 0.001897 and median = 0.000000 ,   mean>median = normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side   
 # ASTV:-  mean =47 and median=49 , mean<median ,  -ve skewness /left skewed/outliers present at left hand side 
 # MSTV :- mean =1.364345 and median =1.200000 , mean>median , normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side
 # ALTV:-mean =10.295650 and median =0.000000 , mean>median , normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side
 # MLTV :- mean =8.280546 and median =7.400000 , mean>median , normal distribution curve with small +ve skewness /right skewed/outliers present on the upper side

# %%
# outliers present : by comparing 75% and max  
#For LB ,ASTV , MSTV , ALTV , MLTV   cloumns :- max > 75% for a huge amount 
#therefore an outliers are present in all these columns
# columns such as FM , AC , UC , DL   :- 75% value is nearly close to max , therefore no outliers are present in this column

# %%
# 3.Data Visualization:-

# %%
df   # all are numerical columns
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006421  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV
# 0      2.4
# 1     10.4
# 2     13.4
# 3     20.1
# ...

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
plt.hist(df.LB)
plt.show()

# %%
plt.hist(df.UC)
plt.show()

# %%
plt.hist(df.AC)
plt.show()

# %%
plt.hist(df.FM)
plt.show()

# %%
sns.histplot(df.DL)
plt.show()

# %%
sns.histplot(df.ASTV)
plt.show()

# %%
sns.histplot(df.MSTV)
plt.show()

# %%
sns.histplot(df.ALTV)
plt.show()

# %%
sns.histplot(df.MLTV)
plt.show()

# %%
df.boxplot()
plt.show()

# %%
sns.boxplot(df.LB)   # outliers are present on the upper  and lower extreme part 
plt.show()

# %%
sns.boxplot(df.AC)   # outliers are present more on upper extreeme part , and few on lower extreme part
plt.show()

# %%
sns.boxplot(df.FM)    # outliers are present more on upper extreeme part , and few on lower extreme part
plt.show()

# %%
sns.boxplot(df.UC) 
plt.show()

# %%
plt.boxplot(df.DL)
plt.show()

# %%
plt.boxplot(df.ASTV)
plt.show()

# %%
plt.boxplot(df.MSTV)
plt.show()

# %%
plt.boxplot(df.ALTV)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr(numeric_only = True)
# Out:
#             LB        AC        FM        UC        DL      ASTV      MSTV  \
# LB    1.000000 -0.082815 -0.006556 -0.164855 -0.156422  0.286417 -0.297341
# AC   -0.082815  1.000000  0.076717  0.093690 -0.102636 -0.274477  0.219313
# FM   -0.006556  0.076717  1.000000 -0.317872 -0.017551  0.155259  0.070719
# UC   -0.164855  0.093690 -0.317872  1.000000  0.268176 -0.217779  0.298321
# DL   -0.156422 -0.102636 -0.017551  0.268176  1.000000 -0.111800  0.566656
# ASTV  0.286417 -0.274477  0.155259 -0.217779 -0.111800  1.000000 -0.433851
# MSTV -0.297341  0.219313  0.070719  0.298321  0.566656 -0.433851  1.000000
# ALTV  0.323779 -0.411227 -0.014093 -0.294710 -0.296515  0.438528 -0.541483
# MLTV -0.042768 -0.153406 -0.037584 -0.072639 -0.241995 -0.326592  0.011775
#
#           ALTV      MLTV
# LB    0.323779 -0.042768
# AC   -0.411227 -0.153406
# FM   -0.014093 -0.037584
# UC   -0.294710 -0.072639
# DL   -0.296515 -0.241995
# ASTV  0.438528 -0.326592
# MSTV -0.541483  0.011775
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.show()
# See sidebar which shows -1 to +1 valuues from bottom to top
# On the side vertical bar Light color indicates positive strong relationship.
# Dark black color indicates strong negative relationship

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()
# colors are representing correlation value also

# %%
# we can change color combination also
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='viridis')
plt.show()

# %%
# 4.Pattern Recognition and Insights:-

# %%
plt.scatter(df['MSTV'],df['ALTV'],color='red')   # strong negative correlation btwn them
plt.xlabel('MSTV')
plt.ylabel('ALTV')
plt.show()

# %%
plt.scatter(df['ASTV'],df['MSTV'],color='red')     # strong negative correlation btwn them
plt.xlabel('ASTV')
plt.ylabel('MSTV')
plt.show()

# %%
plt.scatter(df['ASTV'],df['ALTV'],color='blue')   # strong positive correlation btwn them 
# can say that both are dependent on each other for prediction
plt.xlabel('ASTV')
plt.ylabel('ALTV')
plt.show()

# %%
plt.scatter(df['MSTV'],df['DL'],color='blue')
plt.xlabel('MSTV')
plt.ylabel('DL')
plt.show()

# %%
# most negative relationship between :- MSTV and ALTV   , ASTV and MSTV
# most positive relationship between :- ASTV and ALTV   , DL and MSTV

# %%
#Strong correlations (close to -1 or 1) suggest associations that could be significant for predictive modeling or understanding causal relationships.

# %%
# MSTV , ALTV , ASTV , DL shows a high correlation with outcomes, it could indicate that it’s a strong predictor, suggesting its importance in future analyses.

# %%
# 5.Conclusion:-
#Percentage of Time with Abnormal Long Term Variability" in the FHR , are highly associated with each other

# "Decelerations Late" with respect to uterine contractions, which can be a sign of fetal distress , "Mean Value of Short Term Variability" in the FHR ,
#shows a positive coreelation between them , means they are dependent on each other.which also tells that with increase in DL , MSTV also increses

#"Mean Value of Short Term Variability" in the FHR , "Percentage of Time with Abnormal Long Term Variability" in the FHR , 
#shows a negative correlation between them , means if any one of them increases
